# %% [markdown]
# # Word Counts
#
# When you are working with a pile of twitter data it can be useful to take a look at the types of words that are used in the dataset. To do this we need to create a function that will read through the tweets, and split the text of the tweet on whitespace, normalize (lowercase) the word, and then keep track of the number of times the word was seen using a Python dictionary.

# %%
import json
import gzip

def word_counts(filename):
    counts = {}
    with gzip.open(filename, 'rt') as f:
        for line in f:
            tweet = json.loads(line)
            if 'text' not in tweet:
                break
            for word in tweet['text'].split(' '):
                word = word.lower()
                counts[word] = counts.get(word, 0) + 1
    return counts

# %% [markdown]
# Go ahead and change this filename if you want to look at another dataset:

# %%
counts = word_counts('data/assorted/ferguson-blacklivesmatter.json.gz')

# %% [markdown]
# We can try printing out the results, but the dictionary is unordered, so it's kind of messy.

# %%
print(counts)
# Out:
# {'': 1883, '@dreamdefenders': 8, 'https://t.co/oshu0grght': 1, '#dogs': 1, '@livefreeus': 4, 'indictment': 4, 'movement,': 15, 'http://t.co/mb3nrsbu8a': 1, 'charade': 2, 'w': 12, 'facebook': 2, 'http://t.co/n…': 2, '“@wesleylowery:': 1, 'matter!': 2, '1944': 2, '88': 2, '#thisstopstoday\n\nhttp://t…': 5, 'throughout': 2, 'councilwoman': 1, '@ti_nounou:': 1, 'bath': 2, 'measure': 1, 'soros': 1, 'govern?': 2, 'mess.': 1, 'health': 18, 'bernard': 2, 'darkest': 34, '@rightnowio_feed': 2, 'quote.': 1, 'http://t.co/udctqiam2h': 2, 'http://t.co/gnah0hbgsa': 2, 'http://t.co/2vhg9lqel6”': 3, 'http://t.co/g2kvfzzsst': 1, 'reform': 36, '8pm': 2, 'creepy': 3, 'http://t.co/1tape9ahfg': 1, 'responsible': 5, 'riot)': 1, '\nhttp://t.…': 1, "'necessary'": 7, '\n\nhttp://t.co/uyoflnkz7d\nvia': 1, '@mowords': 2, 'harping': 1, '#ripmikebrown': 13, 'http://t.co/mubowgfa2l': 2, 'http://t.co/t74ll66iru': 2, 'podcast': 1, 'don’t': 28, '#seiu': 1, 'commenting': 1, 'remember.\n\n#fbf': 2, '#worldnews': 1, 'sex': 1, '#madisonshooting': 6, 'http://t.co/ybns8imtnv': 1, 'http://t.co/kbxrrkhz4k': 1, 'monoply:\nhttp://t.co/a1zbcfmhri\n#blacklivesmatter': 3, 'engaging': 7, 'govt': 17, '@pari_passu': 4, 'http://t.co/p4wudcjzrc': 1, 'nazis': 1, 'gobierno': 1, 'http://t.co/9ygd05cell': 1, 'fine-friendly': 1, '‘not': 1, 'plans': 4, 'culture': 8, 'respect!': 81, 'marie': 1, '3/2': 4, 'http://t.co/xu9fr0mcif': 1, 'problem."\n': 1, 'http://t.co/mkk4hz03sw': 1, 'rioting,': 2, 'card,': 1, '"if': 26, 'http://t.co/pkhpcynoxv': 1, 'http://t.co/f7nh7lcxy9': 16, 'justice!!\n\n`': 1, 'http://t.co/gh9b28uabr"': 1, '.@thejusticedept': 7, 'dropping': 9, 'http://t.co/zqvpauonyp': 1, 'food?': 1, '✅http://t.co/kuenzznc4z\n\n': 3, 'diminishing': 1, 'tonight.': 85, '#blacklivesmatter\n7pmtoday\n@hackneyabbott\n@ken4london\n@kate4peace2015\nhttps://t.co/72dq0gartg': 5, 'love.': 2, 'https://t.co/2iey3h3tbe': 1, '@howitzerdoogie:': 2, 'commits': 1, '@afphq': 7, '@harperstewart89:': 1, '@clairecmc,': 43, 'courses': 4, 'http://t.co/l7quqvd9vx': 3, 'utter': 1, 'http://t.co/shutblcc3r': 1, 'student,': 2, 'yuvette': 1, '#doitnow': 1, "coward,didn't": 1, '@unitewomenorg:': 10, 'c…': 2, 'silent,': 2, '😡😡😡': 2, '@doj': 2, 'stream,': 1, 'obama,but': 2, '@fardfollower:': 10, 'http://t.co/1upc…': 17, '“jigaboo': 1, 'http://t.co/p8ww7ibk6u': 1, 'bs': 3, 'introduction': 1, 'http://t.co/65fpx9ny41': 1, "they're": 38, 'http://t.co/9h5abmkl02': 5, 'http://t.co/toqjkh…': 1, 'designed': 2, 'races': 2, '#gma': 1, '@mintpressnews:': 18, 'http://t.co/l5cfmnzysy': 1, '#bla…': 155, '-----&gt;': 2, '#criminaljustice': 1, "aa's": 2, '#livesmatter': 4, '@sharonlstead:': 8, 'uneducated': 2, 'study:': 4, 'http://t.co/ekepyznqu3': 1, 'kate': 1, 'hegemonic': 1, '#blacklivesmatter.': 113, 'allies': 1, '@ninamills': 3, 'http://t.co/lhmqxwt184': 1, 'mansion': 2, 'http://t.co/8onig5rpfh': 1, 'biz': 1, '@talbertswan:': 3, 'akpdensincanşubesineparacezasızulmü': 1, 'http://t.co/nq7mkubusi': 1, 'closure.\nhttp://t.co/hrozq72qqg\n#blacklivesmatter': 3, 'zurück.': 1, 'duh.': 3, 'inste…': 1, 'http://t.co/saidmozlx4': 1, 'etc': 1, 't.': 2, 'http://t.co/bfjlyebhlf': 1, '@chaoticbeaut:': 603, 'amerikkka.': 2, 'yrs': 8, 'standstill.': 2, 'hispanics': 2, "'toxic'": 4, 'emails': 130, 'http://t.co/lww9sdwekg': 2, '#queerabilia\n\nmarketing': 1, '#statenisland': 7, '@mrchuckd': 1, 'http://t.co/cqy49xee5c': 1, 'generation.': 2, '93%': 57, 'segregation,': 2, 'injured,': 1, 'nationwide!': 2, 's/h': 1, '@weebly': 1, 'doesnt': 4, '"@bennydiego:': 2, 'warriors': 1, '#ferguson\n#p2': 24, 'j.': 4, 'http://t.co/ctn6g8moiy': 4, '#nemtsov': 27, 'http://t.co/bhvx9k3amd': 1, '@berniceking.': 2, 'pressure': 3, 't…': 1, 'exercising': 1, 'confronts': 1, 'muni': 4, 'https://t.co/batx67gl6y': 1, 'http://t.co/b7txfailpu': 1, '#justicede…': 6, 'deep!': 1, '@mjhendijani': 1, 'channel': 2, 'validate': 12, 'http://t.co/t5e3ujwjtj': 1, 'sad:': 1, 'http://t.co/rndd7wiinj': 1, 'changers': 1, 'indian,': 1, 'statement': 28, 'details': 7, '@stoneyboboney:': 4,  ...

# %% [markdown]
# We can create a list of the words that are sorted in descending order by the number of times they appear.

# %%
words = sorted(counts, key=counts.get, reverse=True)

# %% [markdown]
# Now we can see how many unique words there are:

# %%
print(len(words))
# Out:
# 18332

# %% [markdown]
# And we can print out the top 25 words with their frequency:

# %%
for word in words[0:25]:
    print(word, counts[word])
# Out:
# #blacklivesmatter 12322
# #ferguson 10851
# rt 10582
# the 5089
# in 4092
# to 3368
# ferguson 3052
# of 3051
# police 2631
# is 2591
# a 2096
#  1883
# for 1720
# i 1584
# was 1399
# and 1366
# have 1327
# on 1290
# #fergusonreport 1255
# not 1242
# &amp; 1185
# black 1088
# from 1032
# he 1019
# after 998
