# %% [markdown]
# # Word Counts
#
# When you are working with a pile of twitter data it can be useful to take a look at the types of words that are used in the dataset. To do this we need to create a function that will read through the tweets, and split the text of the tweet on whitespace, normalize (lowercase) the word, and then keep track of the number of times the word was seen using a Python dictionary.

# %%
import json
import gzip

def word_counts(filename):
    counts = {}
    for line in gzip.open(filename, 'rt'):
        tweet = json.loads(line)
        if 'text' not in tweet:
            break
        for word in tweet['text'].split(' '):
            word = word.lower()
            counts[word] = counts.get(word, 0) + 1
    return counts

# %% [markdown]
# Go ahead and change this filename if you want to look at another dataset:

# %%
counts = word_counts('data/filters/fakePREMIS/author-mentions.json.gz')

# %% [markdown]
# We can try printing out the results, but the dictionary is unordered, so it's kind of messy.

# %%
print(counts)
# Out:
# {'': 1087, 'guilty': 2, "she's": 3, 'mean': 3, 'form': 2, '😀': 3, 'idol,please': 1, 'vc': 4, "riches'": 1, "(he's": 2, 'worthwhile': 1, 'posible:': 1, 'truly': 1, 'http://t.co/1yk5ouuwbh': 1, 'goes!': 1, 'happened': 2, 'aim': 1, 'am': 6, 'choose': 1, '😂❤️': 1, '@nytimes': 1, 'longer': 1, 'answers,': 1, "'starved',": 1, 'weasley': 1, 'looking': 1, 'head': 5, 'nós': 1, 'instantly': 1, '@jk_rowling,': 1, '*bangs': 2, 'dedicated': 1, 'tiffany': 2, '@lolgorges': 1, '😍👸\U0001f3fe👸\U0001f3fc': 1, 'trek:': 16, "i'll": 11, 'creativity!': 1, 'letter?': 1, 'fred': 1, 'begrudgers"': 1, "albus's": 5, 'army': 1, 'hermione,': 1, 'die': 2, 'and': 312, 'kidding.': 1, 'attention': 2, 'ginny': 2, 'moon.': 1, '#8': 1, 'disgrace!': 1, 'beautiful': 5, 'loved': 4, 'tonight:': 3, 'belongs,': 2, 'her': 16, 'jiggery-poking': 1, "weasley's": 1, 'beautiful!': 2, 'https://t.co/ynnglpnjeo': 1, 'wrong.': 5, 'para': 1, 'henry.': 1, 'technically,': 1, 'chrome': 1, 'real?': 1, 'negative': 2, '-or': 1, 'opening': 4, 'entiendo': 1, 'shattered': 1, 'also': 6, 'inside': 1, '"fuck': 1, 'uk': 2, 'collaboration': 2, 'gussied': 1, 'negro': 2, '@nytopinion': 18, '*your*': 1, '@oliverphelps': 1, 'ire*': 1, 'cup': 2, 'the': 663, 'https://t.co/ta7sjron…': 1, 'player': 2, 'women': 1, 'limits': 2, 'cheat': 2, 'boat': 1, 'goodbyeee': 1, 'models.': 1, 'most': 6, 'them': 6, '@valmcdermid': 1, 'lot': 8, 'pension': 1, 'mo…': 2, 'http://t.co/vzbnvgmpfj': 1, 'https://t.co/6xnzhivymx': 176, 'ans': 1, 'readers': 18, '3': 4, 'gnats.': 1, 'burn': 2, 'pls': 1, 'smoking': 2, 'dolores': 1, 'creating': 1, 'spells': 1, 'http://t.co/anrabnffil': 2, 'territory;': 2, "wouldn't": 2, 'yes?': 1, 'writing,': 1, 'moar!': 1, 'when': 24, "won't": 2, 'indeed.': 2, 'yesss': 1, 'released': 1, 'attends': 45, 'seals': 1, 'fan!': 1, '#charliehebdo': 1, 'other?': 1, 'rushdie?': 1, 'yess': 2, 'grow': 1, 'jack': 2, 'oh': 1, 'first': 15, 'death.': 9, 'forte': 1, 'best.': 1, 'good?': 1, 'overweight,': 1, 'longest': 1, 'produced': 2, 'enemy': 14, 'http://t.co/9ffc…': 4, 'lucky.': 1, 'newspapers': 1, 'trabalho': 1, 'cthulhu?': 1, 'him,': 1, '#lovewins': 1, 'players': 2, 'sir😂': 1, 'wanted': 2, 'head,': 1, 'next': 2, "it's": 25, 'attici?': 2, 'retweeted': 1, 'putting': 1, 'tell': 8, 'read': 17, 'treat': 1, 'conformity': 1, 'stub.': 2, '.@kkanzajamil': 2, 'gave': 2, 'agree...': 1, 'wondered': 2, 'does': 5, 'try': 7, 'andy,': 1, 'back': 12, 'work': 9, 'weekly!': 1, 'vem': 1, '@okwonga,': 1, 'timeline,': 1, 'either': 2, "federer's": 22, "dobby's": 1, '#storify': 1, 'q': 1, 'point.': 4, 'phew!': 1, 'book': 108, 'rift!': 1, 'slytherins,': 1, 'strong': 1, 'group': 1, 'dmsss': 1, 'appare…': 1, 'be': 139, '\npq': 1, 'writes': 1, 'try\nhttp://t.co/farnmlauec': 1, '"the': 2, 'freddy': 1, 'has': 111, 'https://t.co/rkevquwb6r': 1, 'favor': 1, "ron's": 1, 'idols': 1, 'insane': 1, 'tweet': 1, 'drunk': 1, '@devonmmurray': 1, '1': 1, '@nytimes:': 2, 'now...': 1, 'story.': 6, 'idiots': 2, 'importante': 1, 'http://t.co/zywezb7hyx': 1, '♥': 2, 'no,': 4, 'wd': 1, 'at': 45, "trolls'": 1, 'grace': 1, 'coming': 3, 'you.': 7, 'true': 2, 'henrys': 1, 'jealousy': 1, 'freedom': 1, '#goserena!': 1, 'w/this': 1, 'turns': 5, 'bit': 1, 'dale.': 1, 'https://t.co/epompvxfcl': 2, 'rule': 1, 'hiii!!': 1, '秋元脱税変態事務所': 1, 'world!': 2, 'too!!!': 1, 'invitation': 1, 'mudblood': 1, 'http://t.co/tmahcfkhvf': 1, 'interviewed': 8, 'queens': 1, 'saying': 5, 'her.': 1, 'muggle': 3, 'get': 11, 'should': 8, 'now': 7, 'will."': 1, '(or': 1, 'nearly': 2, 'acquittal': 1, 'ô': 1, 'hot': 1, '.@bt_betot': 1, '4]': 2, 'dumbledore.': 1, 'liar': 2, 'http://t.co/so7ywzswgt': 22, 'new': 19, 'want,': 4, 'consequence': 2, 'force': 1, '(real': 1, 'harry,hermoine,ron,gini': 1, 'impulse,': 1, 'idea,': 1, 'stub?': 1, 'queen': 5, '#fantasticbeasts': 1, 'her\ngo': 1, 'freakout&gt;': 1, 'ahhh!': 1, 'shouldn’t': 2, 'recommended': 4, 'em...........': 1, 'robinson': 1, 'anti-prequ…': 4, 'just,': 22, 'casa.': 1, 'foods': 1, 'today?!': 1, 'results': 2, 'make': 14, 'http://t.co/wskryc ...

# %% [markdown]
# We can create a list of the words that are sorted in descending order by the number of times they appear.

# %%
words = sorted(counts, key=counts.get, reverse=True)

# %% [markdown]
# Now we can see how many unique words there are:

# %%
print(len(words))
# Out:
# 3210

# %% [markdown]
# And we can print out the top 25 words with their frequency:

# %%
for word in words[0:25]:
    print(word, counts[word])
# Out:
# rt 2150
# @jk_rowling: 1530
#  1087
# you 1087
# she 1001
# don't 994
# than 953
# go 946
# i'm 944
# many 935
# because 924
# people 915
# super-talented 898
# #teamserena 897
# meet 897
# is. 896
# nicer 894
# today, 893
# http://t.c… 893
# @serenawilliams! 893
# the 663
# a 644
# of 427
# is 403
# in 378
